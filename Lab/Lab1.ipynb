# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БВТ2005 Быковская Арина Александровна

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time

# %%
from random import randint
from time import sleep

user_m = input()
user_n = input()
user_min_limit = input()
user_max_limit = input()

def print_mat(mat):
    for line in mat:
        out = [str(el) for el in line]
        print(" ".join(out))


def matrix_generator(m, n, min_lim, max_lim):
    return [[randint(int(min_lim), int(max_lim)) for j in range(int(n))] for i in range(int(m))]

seconds_left = 60
while seconds_left > 0:
    seconds_left -= 1
    generated_matrix = matrix_generator(user_m, user_n, user_min_limit, user_max_limit)
    print(seconds_left)
    print_mat(generated_matrix)
sleep(1)
# Out:
# 10
# 10
# 1
# 10
# 59
# 2 10 3 5 9 8 4 9 3 6
# 8 2 5 5 4 4 4 10 5 7
# 1 8 1 8 5 10 5 5 5 7
# 4 3 1 8 2 1 2 7 9 9
# 7 6 5 6 6 6 10 3 8 9
# 4 4 2 3 1 7 9 7 6 9
# 1 7 8 10 9 4 9 5 6 9
# 8 5 6 8 6 4 1 3 8 5
# 7 4 5 5 5 9 8 2 9 5
# 9 8 9 5 10 7 5 8 5 10
# 58
# 7 6 6 3 2 5 4 10 9 2
# 7 1 10 6 7 7 7 1 4 3
# 4 5 10 2 2 6 2 7 7 3
# 1 4 10 1 6 8 10 7 10 5
# 1 4 5 6 3 7 3 2 3 8
# 4 5 7 8 5 10 2 10 9 7
# 2 10 1 6 3 7 8 2 8 2
# 10 2 2 8 4 7 2 1 3 9
# 2 7 9 9 6 3 10 9 3 7
# 8 10 3 5 10 2 7 3 5 7
# 57
# 10 2 2 7 4 2 4 9 9 10
# 10 9 2 5 4 9 6 2 3 10
# 1 8 5 3 10 8 5 9 6 9
# 9 2 10 6 1 9 4 7 6 3
# 5 6 4 1 7 10 8 8 10 5
# 10 7 2 3 3 2 8 7 4 3
# 9 4 7 2 6 9 2 1 6 3
# 1 3 4 7 7 7 4 3 10 8
# 3 6 8 8 8 2 2 9 1 10
# 4 2 7 3 5 8 3 8 4 5
# 56
# 2 5 2 2 10 10 2 8 4 1
# 10 7 6 7 4 6 3 2 8 3
# 6 5 9 10 6 6 2 10 7 7
# 4 6 4 2 2 3 1 4 7 9
# 1 1 2 3 8 10 9 2 10 3
# 7 3 5 1 6 2 10 2 3 10
# 7 4 6 9 5 1 9 5 5 6
# 2 10 7 2 7 8 2 5 9 5
# 9 3 6 2 6 10 1 1 9 6
# 1 9 2 7 9 1 1 3 3 7
# 2 3 2 8 7 1 10 1 9 8
# 7 9 4 1 5 9 4 10 6 10
# 5 1 3 6 8 4 10 4 3 8
# 4 1 3 6 8 8 1 5 2 8
# 2 7 6 5 3 10 6 3 3 9
# 0
# 6 2 6 3 7 10 2 7 2 5
# 9 1 9 4 4 8 8 5 5 5
# 10 9 1 8 7 2 8 9 2 2
# 6 9 4 5 5 4 2 7 7 8
# 2 8 7 7 7 5 1 1 1 3
# 4 4 6 5 6 10 9 5 5 6
# 9 3 9 8 5 8 6 4 2 5
# 6 5 3 10 1 8 2 9 6 10
# 7 3 8 10 6 10 10 6 4 2
# 5 7 7 1 3 8 8 9 5 3

# %%
# from random import randint


#user_m = input()
#user_n = input()
#user_min_limit = input()
#user_max_limit = input()
#user_m, user_n, user_min_limit, user_max_limit


#def print_mat(mat):
 #   for line in mat:
  #      out = [str(el) for el in line]
   #     print(" ".join(out))


#def matrix_generator(m, n, min_lim, max_lim):
 #   return [[randint(int(min_lim), int(max_lim)) for j in range(int(n))] for i in range(int(m))]


#generated_matrix = matrix_generator(user_m, user_n, user_min_limit, user_max_limit)
#print_mat(generated_matrix)

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import copy

# %%
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
def selection_sort(line):
    for i in range(len(line)):
        temp = line[i]
        index = i
        for j in range(i, len(line)):
            if line[j] < temp:
                temp = line[j]
                index = j
        line[index], line[i] = line[i], temp


matrix = copy.deepcopy(generated_matrix)
t1 = time.time()
for line in matrix:
    line = selection_sort(line)
t2 = time.time()

selection_sort_time = round((t2 - t1) * 1000)

print_mat(matrix)
print(selection_sort_time)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# 0
# --- 2 ms ---

# %%
# Сортировка вставкой.
start_time = time.time()
def insertion_sort(line):
    for i in range(1, len(line)):
        for j in range(i, 0, -1):
            if line[j] < line[j - 1]:
                line[j], line[j - 1] = line [j - 1], line[j]
            else:
                break

matrix = copy.deepcopy(generated_matrix)

t1 = time.time()     

for line in matrix:
    line = insertion_sort(line)

t2 = time.time()

insertion_sort_time = round((t2 - t1) * 1000)   

print_mat(matrix)
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# --- 1 ms ---

# %%
# Сортировка обменом. || Сортировка пузырьком.
start_time = time.time()
def bubble_sort(line):
    n = 1
    for i in range (len(line) - 1):
        for j in range(len(line) - n):
            if line[j] > line[j + 1]:
                line[j], line[j + 1] = line[j + 1], line[j]
        n += 1

matrix = copy.deepcopy(generated_matrix)
        
t1 = time.time()     
for line in matrix:
    line = bubble_sort(line)

t2 = time.time()

bubble_sort_time = round((t2 - t1) * 1000)     
    
print_mat(matrix)
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# --- 1 ms ---

# %%
# Сортировка Шелла.
start_time = time.time()
def shell_sort(line):
    step = len(line) // 2
    while step > 0:
        for i in range(step, len(line)):
            position = i
            value = line[i]
            while position >= step and line[position - step] > value:
                line[position] = line[position - step]
                position -= step
                line[position] = value
        step = step // 2
        
matrix = copy.deepcopy(generated_matrix)
t1 = time.time()
for line in matrix:
    line = shell_sort(line)

t2 = time.time()

shell_sort_time = round((t2 - t1) * 1000)     
    
print_mat(matrix)
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# --- 2 ms ---

# %%
# Быстрая сортировка.
start_time = time.time()
def __quick_sort(line):
    if len(line) == 1 or len(line) == 0:
        return line
    p = line[len(line) - 1]
    l = 0
    for j in range(len(line)):
        if line[j] < p:
            line[j], line[l] = line[l], line[j]
            l += 1
    line.pop(-1)
    line.insert(l, p)
    return __quick_sort(line[0: l]) + [line[l]] + __quick_sort(line[(l + 1): len(line)])


def quick_sort(line):
    p = line[len(line) - 1]
    l = 0
    for j in range(len(line) - 1):
        if line[j] < p:
            line[j], line[l] = line[l], line[j]
            l += 1
    line.pop(-1)
    line.insert(l, p)
    return __quick_sort(line[0: l]) + [line[l]] + __quick_sort(line[(l + 1): len(line)])


matrix = copy.deepcopy(generated_matrix)
new_matrix = []
t1 = time.time()

for line in matrix:
    new_matrix.append(quick_sort(line))

t2 = time.time()

quick_sort_time = round((t2 - t1) * 1000)

print_mat(new_matrix)
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# --- 2 ms ---

# %%
# Турнирная сортировка.
import heapq
start_time = time.time()
def tournament_sort(line):
    heap = []
    heap_size = int(len(line) / 11)
    if heap_size > 63:
        heap_size = 63
    if heap_size < 7:
        heap_size = 7
    if len(line) >= heap_size:
        heap = line[:heap_size]
    else:
        heap = line[:]
    heapq.heapify(heap)
    winners = [float('-inf')]
    losers = []

    i = heap_size
    while i < len(line) or len(heap) > 0:
        heap_top = heapq.heappop(heap)
        if heap_top >= winners[-1]:
            winners.append(heap_top)
        else:
            losers.append(heap_top)

        if i < len(line):
            heapq.heappush(heap, line[i])
        i += 1

    del winners[0]
    line = losers + winners

    if len(losers) > 0:
        return tournament_sort(line)
    return line


matrix = copy.deepcopy(generated_matrix)
new_matrix = []


t1 = time.time()

for line in matrix:
    new_matrix.append(tournament_sort(line))

t2 = time.time()

tournament_sort_time = round((t2 - t1) * 1000) 

print_mat(new_matrix)        
print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 2 2 2 3 5 6 6 7 7 10
# 1 4 4 5 5 5 8 8 9 9
# 1 2 2 2 7 8 8 9 9 10
# 2 4 4 5 5 6 7 7 8 9
# 1 1 1 2 3 5 7 7 7 8
# 4 4 5 5 5 6 6 6 9 10
# 2 3 4 5 5 6 8 8 9 9
# 1 2 3 5 6 6 8 9 10 10
# 2 3 4 6 6 7 8 10 10 10
# 1 3 3 5 5 7 7 8 8 9
# --- 1 ms ---

# %% [markdown]
# ### Вывод

# %%
matrix = copy.deepcopy(generated_matrix)

start_time = time.time()            

for i in range(len(matrix)):
    matrix[i].sort()

default_sort_time = round((time.time() - start_time)*1000)

sort_list = [[selection_sort_time, "selection sort"],
             [bubble_sort_time, "bubble sort"],
             [insertion_sort_time, "insertion sort"],
             [shell_sort_time, "shell sort"],
             [quick_sort_time, "quick sort"],
             [tournament_sort_time, "tour sort"]]
            

sort_list.sort()

for i in range(len(sort_list)):
    print(f"{i + 1} место: {sort_list[i][1]} - {sort_list[i][0]} ms")
# Out:
# 1 место: bubble sort - 0 ms
# 2 место: quick sort - 0 ms
# 3 место: selection sort - 0 ms
# 4 место: shell sort - 0 ms
# 5 место: insertion sort - 1 ms
# 6 место: tour sort - 1 ms
