# %% [markdown]
# # Лабораторная работа №1
# ## Выполнила студентка группы БВТ2005 Быковская Арина Александровна
# ### Задание №1
# необходимо записать в ячейку код и его вывести

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Задание №2
# Написать генератор случайных матриц(многомерных), который принимает опциональные параметры m, n, min_limit, max_limit, где m и n указывают размер матрицы, а min_lim и max_lim - минимальное и максимальное значение для генерируемого числа.

# %%
#вариант решения №1

# %%
import random

# %%
# дано
user_m = input("введите длину матрицы: ")
user_n = input("введите ширину матрицы: ")
user_min_limit = input("введите минимальное число матрицы: ")
user_max_limit = input("введите максимальное число матрицы: ")
user_m, user_n, user_min_limit, user_max_limit

# решение
def matrix(array):
    for x in range(user_n):
        for y in range(user_m):
            print("{:4d}".format(array[i][j]), end="")
        print()

# %%
# вариант решения №2

# %%
import random
import time

# %%
from random import randint
from time import sleep

user_m = input()
user_n = input()
user_min_limit = input()
user_max_limit = input()

def print_mat(mat):
    for line in mat:
        out = [str(el) for el in line]
        print(" ".join(out))


def matrix_generator(m, n, min_lim, max_lim):
    return [[randint(int(min_lim), int(max_lim)) for j in range(int(n))] for i in range(int(m))]

seconds_left = 60
while seconds_left > 0:
    seconds_left -= 1
    generated_matrix = matrix_generator(user_m, user_n, user_min_limit, user_max_limit)
    print(seconds_left)
    print_mat(generated_matrix)
sleep(1)
# Out:
# 10
# 10
# 1
# 8
# 59
# 3 3 8 8 3 3 6 4 7 8
# 1 3 4 7 3 2 1 4 5 8
# 6 5 6 5 6 8 6 7 5 3
# 5 1 3 8 6 1 5 8 7 4
# 1 1 2 8 4 4 4 2 3 8
# 3 1 4 1 5 1 6 8 5 1
# 7 6 4 4 5 8 8 8 4 2
# 7 3 1 5 3 1 6 6 7 6
# 6 7 5 4 3 5 4 7 3 7
# 2 3 1 5 7 4 8 7 5 8
# 58
# 6 3 8 8 2 2 4 3 6 3
# 5 8 7 4 6 5 5 3 8 2
# 8 6 5 2 1 5 8 7 5 4
# 4 3 7 2 2 4 3 3 8 6
# 5 2 4 3 6 8 8 7 7 1
# 1 3 5 4 3 3 5 5 8 2
# 3 5 5 1 5 4 5 8 5 5
# 8 8 7 7 5 7 6 6 1 3
# 8 2 6 7 7 8 6 4 3 6
# 1 1 8 6 8 5 6 2 4 1
# 57
# 2 2 7 7 1 1 8 6 4 8
# 1 4 8 2 4 3 8 4 2 7
# 8 6 3 5 2 8 2 4 3 4
# 6 6 1 1 3 6 1 1 4 1
# 4 6 2 5 7 5 5 2 8 3
# 4 2 7 1 6 1 2 2 7 6
# 1 3 6 6 8 2 3 8 2 4
# 2 5 8 3 5 6 6 2 5 8
# 3 8 4 3 8 8 4 3 7 4
# 2 8 2 8 6 1 6 5 7 8
# 56
# 8 2 1 7 5 2 1 5 8 8
# 3 1 5 2 2 2 3 7 6 2
# 5 1 5 6 1 2 5 4 3 6
# 3 3 5 6 8 2 6 3 2 7
# 7 8 4 3 7 4 7 5 2 3
# 5 3 2 2 3 1 1 6 5 4
# 7 8 6 2 6 7 7 4 4 4
# 2 5 4 3 6 4 2 2 8 3
# 3 1 5 2 1 7 6 5 2 6
# 6 6 1 7 3 7 2 2 6 7
# 6 7 1 7 8 4 1 1 4 5
# 3 2 4 4 5 2 8 8 2 8
# 2 6 4 5 6 4 4 8 4 4
# 7 4 3 8 1 7 8 6 5 8
# 1 2 7 3 7 5 4 8 2 7
# 0
# 6 6 3 3 3 1 3 7 8 2
# 8 3 7 4 3 3 1 1 5 2
# 6 8 3 6 1 4 4 7 1 4
# 6 5 1 2 3 5 5 1 8 8
# 5 1 2 7 7 4 6 3 4 1
# 1 4 5 6 6 7 2 7 6 6
# 2 3 7 7 8 7 3 4 1 3
# 1 8 5 1 7 1 2 6 7 5
# 4 6 5 7 6 5 8 2 5 6
# 8 8 3 1 8 8 2 4 3 1

# %% [markdown]
# # Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со временем стандартной функции сортировки. Испытания проводить на сгенерированных матрицах.

# %%
import copy

# %%
import copy
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.
start_time = time.time()
def selection_sort(line):
    for i in range(len(line)):
        temp = line[i]
        index = i
        for j in range(i, len(line)):
            if line[j] < temp:
                temp = line[j]
                index = j
        line[index], line[i] = line[i], temp


matrix = copy.deepcopy(generated_matrix)
t1 = time.time()
for line in matrix:
    line = selection_sort(line)
t2 = time.time()

selection_sort_time = round((t2 - t1) * 1000)

print_mat(matrix)
print(selection_sort_time)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 1 2 3 3 3 3 6 6 7 8
# 1 1 2 3 3 3 4 5 7 8
# 1 1 3 4 4 4 6 6 7 8
# 1 1 2 3 5 5 5 6 8 8
# 1 1 2 3 4 4 5 6 7 7
# 1 2 4 5 6 6 6 6 7 7
# 1 2 3 3 3 4 7 7 7 8
# 1 1 1 2 5 5 6 7 7 8
# 2 4 5 5 5 6 6 6 7 8
# 1 1 2 3 3 4 8 8 8 8
# 1
# --- 1 ms ---

# %%
# сортировка пузырьком

start_time = time.time()
def bubble_sort(line):
    n = 1
    for i in range (len(line) - 1):
        for j in range(len(line) - n):
            if line[j] > line[j + 1]:
                line[j], line[j + 1] = line[j + 1], line[j]
        n += 1

matrix = copy.deepcopy(generated_matrix)
        
t1 = time.time()     
for line in matrix:
    line = bubble_sort(line)

t2 = time.time()

bubble_sort_time = round((t2 - t1) * 1000)     
    
print_mat(matrix)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 1 2 3 3 3 3 6 6 7 8
# 1 1 2 3 3 3 4 5 7 8
# 1 1 3 4 4 4 6 6 7 8
# 1 1 2 3 5 5 5 6 8 8
# 1 1 2 3 4 4 5 6 7 7
# 1 2 4 5 6 6 6 6 7 7
# 1 2 3 3 3 4 7 7 7 8
# 1 1 1 2 5 5 6 7 7 8
# 2 4 5 5 5 6 6 6 7 8
# 1 1 2 3 3 4 8 8 8 8
# --- 1 ms ---

# %%
# сортировка вставками 

start_time = time.time()

def insertion_sort(line):
    for i in range(1, len(line)):
        for j in range(i, 0, -1):
            if line[j] < line[j - 1]:
                line[j], line[j - 1] = line [j - 1], line[j]
            else:
                break

matrix = copy.deepcopy(generated_matrix)

t1 = time.time()     

for line in matrix:
    line = insertion_sort(line)

t2 = time.time()

insertion_sort_time = round((t2 - t1) * 1000)   

print_mat(matrix)

print("--- {0} ms ---".format(round((time.time() - start_time)*1000)))
# Out:
# 1 2 3 3 3 3 6 6 7 8
# 1 1 2 3 3 3 4 5 7 8
# 1 1 3 4 4 4 6 6 7 8
# 1 1 2 3 5 5 5 6 8 8
# 1 1 2 3 4 4 5 6 7 7
# 1 2 4 5 6 6 6 6 7 7
# 1 2 3 3 3 4 7 7 7 8
# 1 1 1 2 5 5 6 7 7 8
# 2 4 5 5 5 6 6 6 7 8
# 1 1 2 3 3 4 8 8 8 8
# --- 1 ms ---

# %%
# быстрая сортировка 

start_time = time.time()


def quick_sort(line):
    if len(line) == 1 or len(line) == 0:
        return line
    p = line[len(line) - 1]
    l = 0
    for j in range(len(line)):
        if line[j] < p:
            line[j], line[l] = line[l], line[j]
            l += 1
    line.pop(-1)
    line.insert(l, p)
    return __quick_sort(line[0: l]) + [line[l]] + __quick_sort(line[(l + 1): len(line)])


def quick_sort(line):
    p = line[len(line) - 1]
    l = 0
    for j in range(len(line) - 1):
        if line[j] < p:
            line[j], line[l] = line[l], line[j]
            l += 1
    line.pop(-1)
    line.insert(l, p)
    return __quick_sort(line[0: l]) + [line[l]] + __quick_sort(line[(l + 1): len(line)])


matrix = copy.deepcopy(generated_matrix)
new_matrix = []
t1 = time.time()

for line in matrix:
    new_matrix.append(quick_sort(line))

t2 = time.time()

quick_sort_time = round((t2 - t1) * 1000)

print_mat(new_matrix)

print("--- {0} ms ---".format(round((time.time() - start_time) * 1000)))
# Out:
# 1 2 3 3 3 3 6 6 7 8
# 1 1 2 3 3 3 4 5 7 8
# 1 1 3 4 4 4 6 6 7 8
# 1 1 2 3 5 5 5 6 8 8
# 1 1 2 3 4 4 5 6 7 7
# 1 2 4 5 6 6 6 6 7 7
# 1 2 3 3 3 4 7 7 7 8
# 1 1 1 2 5 5 6 7 7 8
# 2 4 5 5 5 6 6 6 7 8
# 1 1 2 3 3 4 8 8 8 8
# --- 3 ms ---

# %%
matrix = copy.deepcopy(generated_matrix)

start_time = time.time()            

for i in range(len(matrix)):
    matrix[i].sort()

default_sort_time = round((time.time() - start_time)*1000)

sort_list = [[selection_sort_time, "selection sort"],
             [bubble_sort_time, "bubble sort"],
             [insertion_sort_time, "insertion sort"],
             [quick_sort_time, "quick sort"]]
            

sort_list.sort()

for i in range(len(sort_list)):
    print(f"{i + 1} место: {sort_list[i][1]} - {sort_list[i][0]} ms")
# Out:
# 1 место: insertion sort - 0 ms
# 2 место: selection sort - 0 ms
# 3 место: bubble sort - 1 ms
# 4 место: quick sort - 1 ms
